# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmashubham240496/KNN/blob/main/KNN_Large_dataset_forward_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Implement Feature Search (using Nearest Neighbor Forward Selection) on Large Dataset

# %%
#Birth date          - 24/04/1996
#Birth Day           - Reading the dataset small data 24th number file from google drive
#Birth Month         - Reading the dataset large data 4th number file from google drive
#Birth Month + Month - Reading the dataset xxxlarge data 8th number file from google drive

from google.colab import drive
import csv
import pandas as pd
import numpy as np

drive.mount('/content/drive')
large_file_path = '/content/drive/MyDrive/Assignment_Knn/KNN_dataset_files/CS170_large_Data__4.txt'

large_df = pd.read_csv(large_file_path, delimiter='  ', header=None)
# Out:
# Mounted at /content/drive
# <ipython-input-1-507ce27992f3>:14: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   large_df = pd.read_csv(large_file_path, delimiter='  ', header=None)

# %%
large_df.shape
# Out:
# (2000, 21)

# %%
def dataset_normalization(input_dataset):
  # Z normalization on all the columns of the dataset except 1st column as it is the lable column
  input_data_array = input_dataset.values
  columns_to_normalize_except_label = np.arange(1, input_data_array.shape[1])

  #calculating the mean and standard deviation for each column except lable column
  columns_respective_means = np.mean(input_data_array[:, columns_to_normalize_except_label], axis=0)
  columns_respective_stds = np.std(input_data_array[:, columns_to_normalize_except_label], axis=0)

  input_data_array[:, columns_to_normalize_except_label] = (input_data_array[:, columns_to_normalize_except_label] - columns_respective_means) / columns_respective_stds

  input_dataset_normalized = pd.DataFrame(input_data_array, columns=input_dataset.columns)

  return input_dataset_normalized

# %%
import numpy as np

def evaluating_accuracy(normalized_input_dataset):
    number_of_correctly_classified_labels = 0
    X = normalized_input_dataset[:, 1:]
    y = normalized_input_dataset[:, 0]

    for i in range(len(normalized_input_dataset)):
        current_row_label = y[i]
        current_row_classification = X[i]

        current_row_nearest_neighbor_distance = float('inf')
        nearest_neighbor_encountered_label = None

        for j in range(len(normalized_input_dataset)):
            if i != j:
                euclidean_distance = np.sqrt(np.sum((current_row_classification - X[j])**2))

                if euclidean_distance < current_row_nearest_neighbor_distance:
                    current_row_nearest_neighbor_distance = euclidean_distance
                    nearest_neighbor_encountered_label = y[j]

        if nearest_neighbor_encountered_label == current_row_label:
            number_of_correctly_classified_labels += 1

    classifier_accuracy_evaluation_metric = number_of_correctly_classified_labels / len(normalized_input_dataset)

    return classifier_accuracy_evaluation_metric * 100

# %%
def forward_selection(normalized_input_dataset):
    print("Beginning Search")
    selected_feature_set = []
    remaining_feature_set = list(range(1, normalized_input_dataset.shape[1]))
    feature_set = {}

    X = normalized_input_dataset.values

    while len(remaining_feature_set) != 0:
        feature_dict = {}

        for c in remaining_feature_set:
            columns_to_include = [0] + [c] + selected_feature_set
            evaluating_performance_dataset = X[:, columns_to_include]
            accuracy_value = evaluating_accuracy(evaluating_performance_dataset)
            columns_to_include.remove(0)

            print()
            print("Using feature(s)", tuple(columns_to_include), "accuracy is", accuracy_value)
            feature_dict[tuple(columns_to_include)] = accuracy_value

        print()
        max_key = max(feature_dict, key=feature_dict.get)
        print("Feature set", tuple(max_key), "was best, accuracy is", feature_dict[max_key])
        print()

        selected_feature_set.insert(0, max_key[0])
        remaining_feature_set.remove(max_key[0])
        feature_set[max_key] = feature_dict[max_key]

    best_feature_list = max(feature_set, key=feature_set.get)

    print()
    print("Finished search!! The best feature subset is", tuple(best_feature_list), "which has an accuracy of", feature_set[best_feature_list])
    return None

# %%
# %%time

large_normalized_df = dataset_normalization(large_df)
forward_selection(large_normalized_df)
# Out:
# Beginning Search
#
# Using feature(s) (1,) accuracy is 69.95
#
# Using feature(s) (2,) accuracy is 73.05
#
# Using feature(s) (3,) accuracy is 71.0
#
# Using feature(s) (4,) accuracy is 71.89999999999999
#
# Using feature(s) (5,) accuracy is 68.75
#
# Using feature(s) (6,) accuracy is 71.55
#
# Using feature(s) (7,) accuracy is 71.2
#
# Using feature(s) (8,) accuracy is 69.55
#
# Using feature(s) (9,) accuracy is 69.6
#
# Using feature(s) (10,) accuracy is 83.15
#
# Using feature(s) (11,) accuracy is 69.39999999999999
#
# Using feature(s) (12,) accuracy is 69.95
#
# Using feature(s) (13,) accuracy is 70.45
#
# Using feature(s) (14,) accuracy is 69.55
#
# Using feature(s) (15,) accuracy is 70.55
#
# Using feature(s) (16,) accuracy is 70.6
#
# Using feature(s) (17,) accuracy is 69.5
#
# Using feature(s) (18,) accuracy is 70.05
#
# Using feature(s) (19,) accuracy is 71.7
#
# Using feature(s) (20,) accuracy is 70.35
#
# Feature set (10,) was best, accuracy is 83.15
#
#
# Using feature(s) (1, 10) accuracy is 82.65
#
# Using feature(s) (2, 10) accuracy is 97.0
#
# Using feature(s) (3, 10) accuracy is 82.8
#
# Using feature(s) (4, 10) accuracy is 83.55
#
# Using feature(s) (5, 10) accuracy is 85.65
#
# Using feature(s) (6, 10) accuracy is 83.45
#
# Using feature(s) (7, 10) accuracy is 83.5
#
# Using feature(s) (8, 10) accuracy is 84.45
#
# Using feature(s) (9, 10) accuracy is 82.55
#
# Using feature(s) (11, 10) accuracy is 82.89999999999999
#
# Using feature(s) (12, 10) accuracy is 82.3
#
# Using feature(s) (13, 10) accuracy is 83.7
#
# Using feature(s) (14, 10) accuracy is 84.15
#
# Using feature(s) (15, 10) accuracy is 82.6
#
# Using feature(s) (16, 10) accuracy is 83.5
#
# Using feature(s) (17, 10) accuracy is 81.75
#
# Using feature(s) (18, 10) accuracy is 83.85000000000001
#
# Using feature(s) (19, 10) accuracy is 83.5
#
# Using feature(s) (20, 10) accuracy is 83.75
#
# Feature set (2, 10) was best, accuracy is 97.0
#
#
# Using feature(s) (1, 2, 10) accuracy is 93.75
#
# Using feature(s) (3, 2, 10) accuracy is 94.5
#
# Using feature(s) (4, 2, 10) accuracy is 94.75
#
# Using feature(s) (5, 2, 10) accuracy is 96.65
#
# Using feature(s) (6, 2, 10) accuracy is 93.60000000000001
#
# Using feature(s) (7, 2, 10) accuracy is 94.69999999999999
#
# Using feature(s) (8, 2, 10) accuracy is 93.45
#
# Using feature(s) (9, 2, 10) accuracy is 95.45
#
# Using feature(s) (11, 2, 10) accuracy is 93.60000000000001
#
# Using feature(s) (12, 2, 10) accuracy is 94.45
#
# Using feature(s) (13, 2, 10) accuracy is 94.5
#
# Using feature(s) (14, 2, 10) accuracy is 93.75
#
# Using feature(s) (15, 2, 10) accuracy is 93.89999999999999
#
# Using feature(s) (16, 2, 10) accuracy is 94.69999999999999
#
# Using feature(s) (17, 2, 10) accuracy is 93.85
#
# Using feature(s) (18, 2, 10) accuracy is 94.65
#
# Using feature(s) (19, 2, 10) accuracy is 94.19999999999999
#
# Using feature(s) (20, 2, 10) accuracy is 94.39999999999999
#
# Feature set (5, 2, 10) was best, accuracy is 96.65
#
#
# Using feature(s) (1, 5, 2, 10) accuracy is 92.55
#
# Using feature(s) (3, 5, 2, 10) accuracy is 93.05
#
# Using feature(s) (4, 5, 2, 10) accuracy is 92.05
#
# Using feature(s) (6, 5, 2, 10) accuracy is 93.30000000000001
#
# Using feature(s) (7, 5, 2, 10) accuracy is 92.9
#
# Using feature(s) (8, 5, 2, 10) accuracy is 92.60000000000001
#
# Using feature(s) (9, 5, 2, 10) accuracy is 92.25
#
# Using feature(s) (11, 5, 2, 10) accuracy is 92.2
#
# Using feature(s) (12, 5, 2, 10) accuracy is 93.30000000000001
#
# Using feature(s) (13, 5, 2, 10) accuracy is 93.35
#
# Using feature(s) (14, 5, 2, 10) accuracy is 93.10000000000001
#
# Using feature(s) (15, 5, 2, 10) accuracy is 91.9
#
# Using feature(s) (16, 5, 2, 10) accuracy is 93.15
#
# Using feature(s) (17, 5, 2, 10) accuracy is 92.55
#
# Using feature(s) (18, 5, 2, 10) accuracy is 93.4
#
# Using feature(s) (19, 5, 2, 10) accuracy is 92.75
#
# Using feature(s) (20, 5, 2, 10) accuracy is 93.30000000000001
#
# Feature set (18, 5, 2, 10) was best, accuracy is 93.4
#
#
# Using feature(s) (1, 18, 5, 2, 10) accuracy is 88.55
#
# Using feature(s) (3, 18, 5, 2, 10) accuracy is 90.64999999999999
#
# Using feature(s) (4, 18, 5, 2, 10) accuracy is 90.7
#
# Using feature(s) (6, 18, 5, 2, 10) accuracy is 89.3
#
# Using feature(s) (7, 18, 5, 2, 10) accuracy is 89.35
#
# Using feature(s) (8, 18, 5, 2, 10) accuracy is 90.55
#
# Using feature(s) (9, 18, 5, 2, 10) accuracy is 88.94999999999999
#
# Using feature(s) (11, 18, 5, 2, 10) accuracy is 89.5
#
# Using feature(s) (12, 18, 5, 2, 10) accuracy is 90.4
#
# Using feature(s) (13, 18, 5, 2, 10) accuracy is 89.9
#
# Using feature(s) (14, 18, 5, 2, 10) accuracy is 89.64999999999999
#
# Using feature(s) (15, 18, 5, 2, 10) accuracy is 88.8
#
# Using feature(s) (16, 18, 5, 2, 10) accuracy is 89.5
#
# Using feature(s) (17, 18, 5, 2, 10) accuracy is 89.55
#
# Using feature(s) (19, 18, 5, 2, 10) accuracy is 90.05
#
# Using feature(s) (20, 18, 5, 2, 10) accuracy is 90.45
#
# Feature set (4, 18, 5, 2, 10) was best, accuracy is 90.7
#
#
# Using feature(s) (1, 4, 18, 5, 2, 10) accuracy is 85.6
#
# Using feature(s) (3, 4, 18, 5, 2, 10) accuracy is 86.75
#
# Using feature(s) (6, 4, 18, 5, 2, 10) accuracy is 87.1
#
# Using feature(s) (7, 4, 18, 5, 2, 10) accuracy is 86.8
#
# Using feature(s) (8, 4, 18, 5, 2, 10) accuracy is 86.45
#
# Using feature(s) (9, 4, 18, 5, 2, 10) accuracy is 85.75
#
# Using feature(s) (11, 4, 18, 5, 2, 10) accuracy is 86.8
#
# Using feature(s) (12, 4, 18, 5, 2, 10) accuracy is 86.1
#
# Using feature(s) (13, 4, 18, 5, 2, 10) accuracy is 86.35000000000001
#
# Using feature(s) (14, 4, 18, 5, 2, 10) accuracy is 85.3
#
# Using feature(s) (15, 4, 18, 5, 2, 10) accuracy is 86.1
#
# Using feature(s) (16, 4, 18, 5, 2, 10) accuracy is 87.0
#
# Using feature(s) (17, 4, 18, 5, 2, 10) accuracy is 87.25
#
# Using feature(s) (19, 4, 18, 5, 2, 10) accuracy is 86.15
#
# Using feature(s) (20, 4, 18, 5, 2, 10) accuracy is 86.75
#
# Feature set (17, 4, 18, 5, 2, 10) was best, accuracy is 87.25
#
#
# Using feature(s) (1, 17, 4, 18, 5, 2, 10) accuracy is 84.2
#
# Using feature(s) (3, 17, 4, 18, 5, 2, 10) accuracy is 84.25
#
# Using feature(s) (6, 17, 4, 18, 5, 2, 10) accuracy is 83.8
#
# Using feature(s) (7, 17, 4, 18, 5, 2, 10) accuracy is 84.05
#
# Using feature(s) (8, 17, 4, 18, 5, 2, 10) accuracy is 83.95
#
# Using feature(s) (9, 17, 4, 18, 5, 2, 10) accuracy is 84.5
#
# Using feature(s) (11, 17, 4, 18, 5, 2, 10) accuracy is 83.95
#
# Using feature(s) (12, 17, 4, 18, 5, 2, 10) accuracy is 83.45
#
# Using feature(s) (13, 17, 4, 18, 5, 2, 10) accuracy is 84.15
#
# Using feature(s) (14, 17, 4, 18, 5, 2, 10) accuracy is 83.1
#
# Using feature(s) (15, 17, 4, 18, 5, 2, 10) accuracy is 84.0
#
# Using feature(s) (16, 17, 4, 18, 5, 2, 10) accuracy is 84.25
#
# Using feature(s) (19, 17, 4, 18, 5, 2, 10) accuracy is 85.7
#
# Using feature(s) (20, 17, 4, 18, 5, 2, 10) accuracy is 84.75
#
# Feature set (19, 17, 4, 18, 5, 2, 10) was best, accuracy is 85.7
#
#
# Using feature(s) (1, 19, 17, 4, 18, 5, 2, 10) accuracy is 80.95
#
# Using feature(s) (3, 19, 17, 4, 18, 5, 2, 10) accuracy is 81.85
#
# Using feature(s) (6, 19, 17, 4, 18, 5, 2, 10) accuracy is 83.1
#
# Using feature(s) (7, 19, 17, 4, 18, 5, 2, 10) accuracy is 82.65
#
# Using feature(s) (8, 19, 17, 4, 18, 5, 2, 10) accuracy is 82.85
#
# Using feature(s) (9, 19, 17, 4, 18, 5, 2, 10) accuracy is 82.39999999999999
#
# Using feature(s) (11, 19, 17, 4, 18, 5, 2, 10) accuracy is 81.85
#
# Using feature(s) (12, 19, 17, 4, 18, 5, 2, 10) accuracy is 82.39999999999999
#
# Using feature(s) (13, 19, 17, 4, 18, 5, 2, 10) accuracy is 83.2
#
# Using feature(s) (14, 19, 17, 4, 18, 5, 2, 10) accuracy is 82.19999999999999
#
# Using feature(s) (15, 19, 17, 4, 18, 5, 2, 10) accuracy is 82.89999999999999
#
# Using feature(s) (16, 19, 17, 4, 18, 5, 2, 10) accuracy is 83.05
#
# Using feature(s) (20, 19, 17, 4, 18, 5, 2, 10) accuracy is 83.65
#
# Feature set (20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 83.65
#
#
# Using feature(s) (1, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 79.9
#
# Using feature(s) (3, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 79.65
#
# Using feature(s) (6, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 81.05
#
# Using feature(s) (7, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 79.80000000000001
#
# Using feature(s) (8, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 80.60000000000001
#
# Using feature(s) (9, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 80.85
#
# Using feature(s) (11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 82.19999999999999
#
# Using feature(s) (12, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 81.10000000000001
#
# Using feature(s) (13, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 80.95
#
# Using feature(s) (14, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 81.39999999999999
#
# Using feature(s) (15, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 80.60000000000001
#
# Using feature(s) (16, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 81.2
#
# Feature set (11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 82.19999999999999
#
#
# Using feature(s) (1, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 77.5
#
# Using feature(s) (3, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 77.55
#
# Using feature(s) (6, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 79.05
#
# Using feature(s) (7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 79.9
#
# Using feature(s) (8, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 79.9
#
# Using feature(s) (9, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 79.35
#
# Using feature(s) (12, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 77.95
#
# Using feature(s) (13, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 79.7
#
# Using feature(s) (14, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 78.7
#
# Using feature(s) (15, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 78.05
#
# Using feature(s) (16, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 79.75
#
# Feature set (7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 79.9
#
#
# Using feature(s) (1, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 76.05
#
# Using feature(s) (3, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 77.7
#
# Using feature(s) (6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 78.45
#
# Using feature(s) (8, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 77.95
#
# Using feature(s) (9, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 78.4
#
# Using feature(s) (12, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 76.4
#
# Using feature(s) (13, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 76.85
#
# Using feature(s) (14, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 76.64999999999999
#
# Using feature(s) (15, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 77.05
#
# Using feature(s) (16, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 77.55
#
# Feature set (6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 78.45
#
#
# Using feature(s) (1, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 75.94999999999999
#
# Using feature(s) (3, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 75.9
#
# Using feature(s) (8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 77.14999999999999
#
# Using feature(s) (9, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 76.4
#
# Using feature(s) (12, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 75.94999999999999
#
# Using feature(s) (13, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 75.64999999999999
#
# Using feature(s) (14, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 75.6
#
# Using feature(s) (15, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 76.55
#
# Using feature(s) (16, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 75.35
#
# Feature set (8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 77.14999999999999
#
#
# Using feature(s) (1, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.5
#
# Using feature(s) (3, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 75.5
#
# Using feature(s) (9, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 75.8
#
# Using feature(s) (12, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.45
#
# Using feature(s) (13, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.65
#
# Using feature(s) (14, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 75.3
#
# Using feature(s) (15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 76.25
#
# Using feature(s) (16, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.7
#
# Feature set (15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 76.25
#
#
# Using feature(s) (1, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.4
#
# Using feature(s) (3, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 73.65
#
# Using feature(s) (9, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 73.8
#
# Using feature(s) (12, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 73.5
#
# Using feature(s) (13, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.5
#
# Using feature(s) (14, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.2
#
# Using feature(s) (16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.75
#
# Feature set (16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 74.75
#
#
# Using feature(s) (1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.65
#
# Using feature(s) (3, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 72.8
#
# Using feature(s) (9, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 72.75
#
# Using feature(s) (12, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 73.65
#
# Using feature(s) (13, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 73.5
#
# Using feature(s) (14, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.0
#
# Feature set (1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 74.65
#
#
# Using feature(s) (3, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 72.3
#
# Using feature(s) (9, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 72.45
#
# Using feature(s) (12, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 72.45
#
# Using feature(s) (13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 74.25
#
# Using feature(s) (14, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 73.2
#
# Feature set (13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 74.25
#
#
# Using feature(s) (3, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 72.5
#
# Using feature(s) (9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 72.55
#
# Using feature(s) (12, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 71.89999999999999
#
# Using feature(s) (14, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 72.3
#
# Feature set (9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 72.55
#
#
# Using feature(s) (3, 9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 70.65
#
# Using feature(s) (12, 9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 70.75
#
# Using feature(s) (14, 9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 70.25
#
# Feature set (12, 9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 70.75
#
#
# Using feature(s) (3, 12, 9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 70.8
#
# Using feature(s) (14, 12, 9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 71.05
#
# Feature set (14, 12, 9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 71.05
#
#
# Using feature(s) (3, 14, 12, 9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) accuracy is 71.55
#
# Feature set (3, 14, 12, 9, 13, 1, 16, 15, 8, 6, 7, 11, 20, 19, 17, 4, 18, 5, 2, 10) was best, accuracy is 71.55
#
#
# Finished search!! The best feature subset is (2, 10) which has an accuracy of 97.0
# CPU times: user 1h 22min 50s, sys: 8.16 s, total: 1h 22min 58s
# Wall time: 1h 23min 30s
